# %%
import matplotlib.pyplot as plt
import numpy as np

# Создаем массив значений x от 0 до 10 с достаточным количеством точек
x = np.linspace(0, 10, 500)

# Вычисляем значения y = 10x + 20x^2 + sqrt(x)
y = 10*x + 20*x**2 + np.sqrt(x)

# Создаем график
plt.plot(x, y)
plt.title('График функции y = 10x + 20x^2 + sqrt(x)')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)  # Добавляем сетку
plt.show()  # Показываем график
